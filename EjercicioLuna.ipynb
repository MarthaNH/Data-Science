# %% [markdown]
# <a href="https://colab.research.google.com/github/MarthaNH/Data-Science/blob/main/EjercicioLuna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
imagen=Image.open("/luna.jpg")

# %%
im_datos = np.array(imagen)
x, y, z = im_datos.shape

for i in range (x):
    for j in range (y):
        if im_datos[i][j][0] == 0 and im_datos[i][j][1] == 0 and im_datos[i][j][2] == 0:
            im_datos[i][j] = [250,65,0]
            
fig,ax = plt.subplots(figsize=(5,5))
ax.imshow(im_datos)
